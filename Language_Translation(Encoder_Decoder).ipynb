# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.layers import LSTM,Input,Dense
from keras.models import Model

# %%
# !!curl -O http://www.manythings.org/anki/deu-eng.zip
# !!unzip deu-eng.zip
# Out:
# ['Archive:  deu-eng.zip',
#  'replace deu.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y',
#  '  inflating: deu.txt                 ',
#  'replace _about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y',
#  '  inflating: _about.txt              ']

# %%
batch_size = 64  # Batch size for training
epochs = 100  # Number of epochs to train for
latent_dim = 256  # Latent dimensionality of encoding space
num_samples = 50000  # Number of samples to train on
# Path to the data txt file
data_path = "deu.txt"

# %%
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 50000
# Number of unique input tokens: 76
# Number of unique output tokens: 92
# Max sequence length for inputs: 21
# Max sequence length for outputs: 122

# %%
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=100,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 625/625 [==============================] - 46s 62ms/step - loss: 0.4570 - accuracy: 0.8795 - val_loss: 0.3969 - val_accuracy: 0.8846
# Epoch 2/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.2817 - accuracy: 0.9179 - val_loss: 0.3155 - val_accuracy: 0.9074
# Epoch 3/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.2391 - accuracy: 0.9299 - val_loss: 0.2823 - val_accuracy: 0.9165
# Epoch 4/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.2148 - accuracy: 0.9367 - val_loss: 0.2607 - val_accuracy: 0.9228
# Epoch 5/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.1981 - accuracy: 0.9418 - val_loss: 0.2468 - val_accuracy: 0.9272
# Epoch 6/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.1854 - accuracy: 0.9456 - val_loss: 0.2351 - val_accuracy: 0.9306
# Epoch 7/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1754 - accuracy: 0.9485 - val_loss: 0.2286 - val_accuracy: 0.9327
# Epoch 8/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1673 - accuracy: 0.9508 - val_loss: 0.2220 - val_accuracy: 0.9346
# Epoch 9/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1602 - accuracy: 0.9529 - val_loss: 0.2183 - val_accuracy: 0.9357
# Epoch 10/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1540 - accuracy: 0.9547 - val_loss: 0.2146 - val_accuracy: 0.9369
# Epoch 11/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1485 - accuracy: 0.9563 - val_loss: 0.2094 - val_accuracy: 0.9387
# Epoch 12/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1434 - accuracy: 0.9577 - val_loss: 0.2067 - val_accuracy: 0.9397
# Epoch 13/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1389 - accuracy: 0.9590 - val_loss: 0.2051 - val_accuracy: 0.9403
# Epoch 14/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1347 - accuracy: 0.9603 - val_loss: 0.2048 - val_accuracy: 0.9407
# Epoch 15/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1309 - accuracy: 0.9614 - val_loss: 0.2032 - val_accuracy: 0.9414
# Epoch 16/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1274 - accuracy: 0.9624 - val_loss: 0.2020 - val_accuracy: 0.9419
# Epoch 17/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1242 - accuracy: 0.9634 - val_loss: 0.2006 - val_accuracy: 0.9425
# Epoch 18/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1212 - accuracy: 0.9642 - val_loss: 0.2018 - val_accuracy: 0.9425
# Epoch 19/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1183 - accuracy: 0.9650 - val_loss: 0.2028 - val_accuracy: 0.9422
# Epoch 20/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1157 - accuracy: 0.9658 - val_loss: 0.2019 - val_accuracy: 0.9429
# Epoch 21/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.1131 - accuracy: 0.9665 - val_loss: 0.2026 - val_accuracy: 0.9428
# Epoch 22/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1107 - accuracy: 0.9673 - val_loss: 0.2035 - val_accuracy: 0.9432
# Epoch 23/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1085 - accuracy: 0.9678 - val_loss: 0.2050 - val_accuracy: 0.9431
# Epoch 24/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1063 - accuracy: 0.9685 - val_loss: 0.2039 - val_accuracy: 0.9433
# Epoch 25/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.1042 - accuracy: 0.9691 - val_loss: 0.2065 - val_accuracy: 0.9430
# Epoch 26/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.1022 - accuracy: 0.9696 - val_loss: 0.2072 - val_accuracy: 0.9431
# Epoch 27/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.1003 - accuracy: 0.9702 - val_loss: 0.2085 - val_accuracy: 0.9428
# Epoch 28/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0986 - accuracy: 0.9707 - val_loss: 0.2103 - val_accuracy: 0.9428
# Epoch 29/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0968 - accuracy: 0.9712 - val_loss: 0.2114 - val_accuracy: 0.9430
# Epoch 30/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0950 - accuracy: 0.9718 - val_loss: 0.2137 - val_accuracy: 0.9424
# Epoch 31/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0936 - accuracy: 0.9721 - val_loss: 0.2142 - val_accuracy: 0.9430
# Epoch 32/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0920 - accuracy: 0.9726 - val_loss: 0.2177 - val_accuracy: 0.9425
# Epoch 33/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0904 - accuracy: 0.9730 - val_loss: 0.2174 - val_accuracy: 0.9425
# Epoch 34/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0890 - accuracy: 0.9734 - val_loss: 0.2196 - val_accuracy: 0.9426
# Epoch 35/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0876 - accuracy: 0.9738 - val_loss: 0.2213 - val_accuracy: 0.9424
# Epoch 36/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0862 - accuracy: 0.9741 - val_loss: 0.2225 - val_accuracy: 0.9426
# Epoch 37/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0848 - accuracy: 0.9746 - val_loss: 0.2239 - val_accuracy: 0.9421
# Epoch 38/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0836 - accuracy: 0.9749 - val_loss: 0.2279 - val_accuracy: 0.9419
# Epoch 39/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0823 - accuracy: 0.9752 - val_loss: 0.2300 - val_accuracy: 0.9417
# Epoch 40/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0812 - accuracy: 0.9756 - val_loss: 0.2303 - val_accuracy: 0.9416
# Epoch 41/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0800 - accuracy: 0.9759 - val_loss: 0.2321 - val_accuracy: 0.9417
# Epoch 42/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0789 - accuracy: 0.9762 - val_loss: 0.2336 - val_accuracy: 0.9416
# Epoch 43/100
# 625/625 [==============================] - 38s 61ms/step - loss: 0.0778 - accuracy: 0.9765 - val_loss: 0.2361 - val_accuracy: 0.9413
# Epoch 44/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0768 - accuracy: 0.9768 - val_loss: 0.2379 - val_accuracy: 0.9411
# Epoch 45/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0757 - accuracy: 0.9771 - val_loss: 0.2398 - val_accuracy: 0.9412
# Epoch 46/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0747 - accuracy: 0.9774 - val_loss: 0.2409 - val_accuracy: 0.9411
# Epoch 47/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0747 - accuracy: 0.9775 - val_loss: 0.2443 - val_accuracy: 0.9406
# Epoch 48/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0729 - accuracy: 0.9778 - val_loss: 0.2467 - val_accuracy: 0.9402
# Epoch 49/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0738 - accuracy: 0.9778 - val_loss: 0.2473 - val_accuracy: 0.9404
# Epoch 50/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0713 - accuracy: 0.9783 - val_loss: 0.2488 - val_accuracy: 0.9406
# Epoch 51/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0703 - accuracy: 0.9786 - val_loss: 0.2509 - val_accuracy: 0.9402
# Epoch 52/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0694 - accuracy: 0.9788 - val_loss: 0.2525 - val_accuracy: 0.9402
# Epoch 53/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0686 - accuracy: 0.9790 - val_loss: 0.2558 - val_accuracy: 0.9400
# Epoch 54/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0678 - accuracy: 0.9793 - val_loss: 0.2564 - val_accuracy: 0.9401
# Epoch 55/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0670 - accuracy: 0.9796 - val_loss: 0.2579 - val_accuracy: 0.9398
# Epoch 56/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0663 - accuracy: 0.9796 - val_loss: 0.2579 - val_accuracy: 0.9400
# Epoch 57/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0656 - accuracy: 0.9799 - val_loss: 0.2612 - val_accuracy: 0.9398
# Epoch 58/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0821 - accuracy: 0.9776 - val_loss: 0.2629 - val_accuracy: 0.9396
# Epoch 59/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0641 - accuracy: 0.9804 - val_loss: 0.2653 - val_accuracy: 0.9393
# Epoch 60/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0635 - accuracy: 0.9804 - val_loss: 0.2669 - val_accuracy: 0.9392
# Epoch 61/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0629 - accuracy: 0.9806 - val_loss: 0.2698 - val_accuracy: 0.9391
# Epoch 62/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0621 - accuracy: 0.9808 - val_loss: 0.2719 - val_accuracy: 0.9388
# Epoch 63/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0615 - accuracy: 0.9809 - val_loss: 0.2727 - val_accuracy: 0.9391
# Epoch 64/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0609 - accuracy: 0.9812 - val_loss: 0.2742 - val_accuracy: 0.9387
# Epoch 65/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0603 - accuracy: 0.9813 - val_loss: 0.2757 - val_accuracy: 0.9389
# Epoch 66/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0603 - accuracy: 0.9812 - val_loss: 0.2779 - val_accuracy: 0.9387
# Epoch 67/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0593 - accuracy: 0.9816 - val_loss: 0.2807 - val_accuracy: 0.9387
# Epoch 68/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0586 - accuracy: 0.9817 - val_loss: 0.2823 - val_accuracy: 0.9385
# Epoch 69/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0581 - accuracy: 0.9819 - val_loss: 0.2826 - val_accuracy: 0.9384
# Epoch 70/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0581 - accuracy: 0.9819 - val_loss: 0.2868 - val_accuracy: 0.9381
# Epoch 71/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0572 - accuracy: 0.9822 - val_loss: 0.2878 - val_accuracy: 0.9380
# Epoch 72/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0566 - accuracy: 0.9823 - val_loss: 0.2874 - val_accuracy: 0.9384
# Epoch 73/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0560 - accuracy: 0.9825 - val_loss: 0.2879 - val_accuracy: 0.9380
# Epoch 74/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0554 - accuracy: 0.9827 - val_loss: 0.2900 - val_accuracy: 0.9382
# Epoch 75/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0549 - accuracy: 0.9828 - val_loss: 0.2923 - val_accuracy: 0.9383
# Epoch 76/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0545 - accuracy: 0.9829 - val_loss: 0.2933 - val_accuracy: 0.9381
# Epoch 77/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0541 - accuracy: 0.9830 - val_loss: 0.2972 - val_accuracy: 0.9379
# Epoch 78/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0537 - accuracy: 0.9831 - val_loss: 0.2994 - val_accuracy: 0.9375
# Epoch 79/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0533 - accuracy: 0.9833 - val_loss: 0.2977 - val_accuracy: 0.9380
# Epoch 80/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0527 - accuracy: 0.9833 - val_loss: 0.3006 - val_accuracy: 0.9379
# Epoch 81/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0523 - accuracy: 0.9835 - val_loss: 0.3029 - val_accuracy: 0.9377
# Epoch 82/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0519 - accuracy: 0.9836 - val_loss: 0.3049 - val_accuracy: 0.9375
# Epoch 83/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0515 - accuracy: 0.9837 - val_loss: 0.3060 - val_accuracy: 0.9374
# Epoch 84/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0511 - accuracy: 0.9838 - val_loss: 0.3073 - val_accuracy: 0.9377
# Epoch 85/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0506 - accuracy: 0.9839 - val_loss: 0.3106 - val_accuracy: 0.9374
# Epoch 86/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0503 - accuracy: 0.9840 - val_loss: 0.3097 - val_accuracy: 0.9370
# Epoch 87/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0499 - accuracy: 0.9841 - val_loss: 0.3106 - val_accuracy: 0.9373
# Epoch 88/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0496 - accuracy: 0.9842 - val_loss: 0.3157 - val_accuracy: 0.9370
# Epoch 89/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0493 - accuracy: 0.9844 - val_loss: 0.3157 - val_accuracy: 0.9369
# Epoch 90/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0490 - accuracy: 0.9844 - val_loss: 0.3171 - val_accuracy: 0.9370
# Epoch 91/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0486 - accuracy: 0.9845 - val_loss: 0.3182 - val_accuracy: 0.9373
# Epoch 92/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0484 - accuracy: 0.9845 - val_loss: 0.3187 - val_accuracy: 0.9371
# Epoch 93/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0477 - accuracy: 0.9848 - val_loss: 0.3207 - val_accuracy: 0.9368
# Epoch 94/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0476 - accuracy: 0.9848 - val_loss: 0.3194 - val_accuracy: 0.9372
# Epoch 95/100
# 625/625 [==============================] - 38s 60ms/step - loss: 0.0523 - accuracy: 0.9836 - val_loss: 0.3227 - val_accuracy: 0.9369
# Epoch 96/100
# 625/625 [==============================] - 37s 60ms/step - loss: 0.0471 - accuracy: 0.9849 - val_loss: 0.3244 - val_accuracy: 0.9366
# Epoch 97/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0468 - accuracy: 0.9851 - val_loss: 0.3273 - val_accuracy: 0.9366
# Epoch 98/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0464 - accuracy: 0.9851 - val_loss: 0.3244 - val_accuracy: 0.9368
# Epoch 99/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0460 - accuracy: 0.9852 - val_loss: 0.3290 - val_accuracy: 0.9366
# Epoch 100/100
# 625/625 [==============================] - 37s 59ms/step - loss: 0.0458 - accuracy: 0.9853 - val_loss: 0.3303 - val_accuracy: 0.9365
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets

# %%
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,), name="input_3")
decoder_state_input_c = keras.Input(shape=(latent_dim,), name="input_6")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(10):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Geh, suche es.
#
# -
# Input sentence: Hi.
# Decoded sentence: Hallo!
#
# -
# Input sentence: Hi.
# Decoded sentence: Hallo!
#
# -
# Input sentence: Run!
# Decoded sentence: Lauf!
#
# -
# Input sentence: Run.
# Decoded sentence: Lauf!
#
# -
# Input sentence: Wow!
# Decoded sentence: Vergrüge!
#
# -
# Input sentence: Wow!
# Decoded sentence: Vergrüge!
#
# -
# Input sentence: Duck!
# Decoded sentence: Komm dir hin!
#
# -
# Input sentence: Fire!
# Decoded sentence: Feuer!
#
# -
# Input sentence: Help!
# Decoded sentence: Hilfe!
